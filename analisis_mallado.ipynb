# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
A = pd.read_csv('tabla_malla.csv',decimal=',')

data = A.apply(pd.to_numeric, errors='coerce')
data
# Out:
#      Ra  Malla            Ux            Uy            Uz             U  \
# 0  1700    NaN  7.570000e-08 -3.780000e-06  0.000000e+00  3.784340e-06
# 1  1700    NaN -8.192920e-07 -3.314750e-09  0.000000e+00  8.192990e-07
# 2  1700    NaN  8.420000e-07  3.340000e-08  5.710000e-28  8.424050e-07
# 3  1800    NaN -5.870000e-05 -2.981180e-03  0.000000e+00  2.981757e-03
# 4  1800    NaN  2.010630e-06 -3.606390e-04  0.000000e+00  3.606450e-04
# 5  1800    NaN -1.260000e-05  7.420000e-07 -2.400000e-27  1.266720e-05
# 6  1900    NaN -8.910000e-05 -4.275740e-03  0.000000e+00  4.276668e-03
# 7  1900    NaN  4.653980e-05  3.751220e-03  4.450010e-22  3.751509e-03
# 8  1900    NaN -3.200000e-07 -1.064900e-03  0.000000e+00  1.064900e-03
#
#           Uxmax         Uxmin         Uymax         Uymin
# 0  3.640000e-06 -3.650000e-06  3.660000e-06 -3.780000e-06
# 1  8.190020e-07 -8.192920e-07  8.043110e-07 -8.007150e-07
# 2  8.420000e-07 -8.410000e-07  7.890000e-07 -8.140000e-07
# ...

# %%
fig, ax = plt.subplots(1,2,figsize=(10, 4))
ax1,ax2 = ax
fig.suptitle('Influencia del tamaño de malla', fontsize=20)
width = 1/5
ticks = np.arange(1)

ax1.set_ylabel('Velocidad vertical máxima [m/s]')

ax1.bar(ticks + width, data.loc[0,'Uymax'], width, align="center", label='Malla gruesa', color="red")
ax1.bar(ticks, data.loc[1,'Uymax'], width, align="center", label='Malla media',color="blue")
ax1.bar(ticks - width, data.loc[2,'Uymax'], width, align="center", label='Malla fina', color="green")

ax1.set_xticks([])
ax1.set_xlabel('Ra = 1700')
ax1.legend(loc='best')
fig.tight_layout()

ticks2 = np.arange(2)

ax2.bar(ticks2 + width, (data.loc[3,'Uymax'], data.loc[6,'Uymax']), width, align="center", label='Malla gruesa', color="red")
ax2.bar(ticks2, (data.loc[4,'Uymax'], data.loc[7,'Uymax']), width, align="center", label='Malla media',color="blue")
ax2.bar(ticks2 - width, (data.loc[5,'Uymax'],data.loc[8,'Uymax']), width, align="center", label='Malla fina', color="green")

plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
ax2.tick_params(axis='both', which='both', length=0)

ax2.set_xticks(ticks2)
ax2.set_xticklabels(('Ra = 1800', 'Ra = 1900'))
ax2.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="1000">
