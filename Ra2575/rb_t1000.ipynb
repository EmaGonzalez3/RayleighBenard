# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#x_data = np.array([2575, 2700, 2800, 2900, 3000, 3175, 3350, 4000, 4900])
#y_data = np.array([0.001254838, 0.002446186, 0.004017219, 0.006171251, 0.008501493, 0.011453243, 0.012547801, 0.015113566, 0.018662084])

# %%
A = pd.read_csv('rbt1000.csv',decimal=',')

data = A.apply(pd.to_numeric, errors='coerce')
Ra,Ux,Uy,Uz,U,Uxmax = data.to_numpy().T

# %%
fig, ax = plt.subplots(1,1,figsize=(6, 4))
plt.plot(Ra, Uxmax, 'o--')
plt.xlabel('Ra', fontsize=16)
plt.ylabel('Ux (máxima) [m/s]')
plt.title('Influencia del tiempo de simulación')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
x_data2 = np.array([2575, 2700, 2800, 2900, 3000, 3175, 3350, 4000, 4900])
y_data2 = np.array([0.00121617, 0.00235982, 0.00386102, 0.00591502, 0.00813374, 1.06E-02, 0.011587, 0.0144931, 0.0164155])
